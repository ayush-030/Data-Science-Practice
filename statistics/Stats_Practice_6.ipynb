# %% [markdown]
# <a href="https://colab.research.google.com/github/ayush-030/Data-Science-Practice/blob/main/statistics/Stats_Practice_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Central Limit Theorem

# %%
pop_data = [np.random.randint(10, 100) for i in range(1000)]
pop_table = pd.DataFrame(pop_data, columns=['Pop_Data'])
pop_table
# Out:
#      Pop_Data
# 0          10
# 1          36
# 2          78
# 3          24
# 4          63
# ..        ...
# 995        30
# 996        98
# 997        47
# 998        90
# 999        34
#
# [1000 rows x 1 columns]

# %%
np.mean(pop_data)
# Out:
# np.float64(54.961)

# %%
plt.figure(figsize=(4,3))
sns.kdeplot(x = "Pop_Data", data = pop_table)
plt.show()

# %%
sample_mean = []
for no_sample in range(50):
  sample_data = []
  for data in range(500):
    sample_data.append(np.random.choice(pop_data))
  sample_mean.append(np.mean(sample_data))

# %%
# Almost the same mean as overall population data(pop_data)
np.mean(sample_mean)
# Out:
# np.float64(54.6144)

# %%
sample_M = pd.DataFrame(sample_mean, columns=['Sample_Mean'])
sample_M
# Out:
#     Sample_Mean
# 0        54.160
# 1        55.658
# 2        54.702
# 3        53.948
# 4        52.730
# 5        54.638
# 6        56.526
# 7        54.350
# 8        54.134
# 9        52.926
# 10       56.852
# 11       55.530
# 12       55.050
# 13       54.636
# 14       56.656
# 15       54.194
# 16       55.334
# 17       56.576
# 18       55.012
# 19       53.522
# 20       53.226
# 21       55.432
# 22       55.106
# 23       53.594
# 24       55.274
# 25       54.518
# 26       54.080
# 27       53.666
# 28       53.118
# 29       54.324
# 30       55.304
# 31       54.734
# 32       54.740
# 33       53.952
# 34       54.420
# 35       55.284
# 36       53.446
# 37       55.968
# 38       56.300
# 39       53.928
# 40       51.982
# 41       54.850
# 42       57.030
# 43       55.408
# 44       54.720
# 45       55.174
# 46       53.544
# 47       52.492
# 48       54.300
# 49       53.672

# %%
# Likely more normally distributed as compared to the overall population data's distribution
plt.figure(figsize=(4,3))
sns.kdeplot(x = "Sample_Mean", data = sample_M)
plt.show()
